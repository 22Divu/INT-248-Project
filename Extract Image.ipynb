# %%
import pandas as pd
import cv2

# %%
df=pd.read_csv("hmnist_28_28_RGB.csv")
df
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0            192        153        193        195        155        192
# 1             25         14         30         68         48         75
# 2            192        138        153        200        145        163
# 3             38         19         30         95         59         72
# 4            158        113        139        194        144        174
# ...          ...        ...        ...        ...        ...        ...
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# ...

# %%
df.label.value_counts()
# Out:
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: label, dtype: int64

# %%
y2=df[df.label==6]  # 2
y0=df[df.label==4]  # 0

# %%
y1=pd.concat([df[df.label<4], df[df.label==5]]) #1

# %%
y1.label=1

# %%
y0.label=2
y2.label=0
# Out:
# c:\python 37\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
y1
# Out:
#       pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0           192        153        193        195        155        192
# 1            25         14         30         68         48         75
# 2           192        138        153        200        145        163
# 3            38         19         30         95         59         72
# 4           158        113        139        194        144        174
# ...         ...        ...        ...        ...        ...        ...
# 2457        230        172        198        229        166        195
# 2458        237        167        185        239        172        189
# 2459        221        151        175        223        153        176
# 2460        243        199        212        244        198        213
# 2461        238        194        217        243        200        223
#
#       pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# ...

# %%
y0
# Out:
#       pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 64          163        135        159        167        140        166
# 1210        229        145        164        229        138        162
# 2976        237        160        159        239        160        161
# 2977        214        129        123        217        131        128
# 2978        215        156        171        215        158        173
# ...         ...        ...        ...        ...        ...        ...
# 9682         10          6          5         28         23         29
# 9683        194        173        176        202        182        184
# 9684         48         35         34        109         86         81
# 9685        151        116        123        204        162        174
# 9686         19          9         13         16          7         11
#
#       pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# ...

# %%
y2
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 1211         151        126        129        161        132        138
# 1212         201        172        187        201        172        187
# 1213         137        117        136        145        124        144
# 1214           8          1          7         53         34         51
# 1215         223        204        225        235        218        240
# ...          ...        ...        ...        ...        ...        ...
# 2319         186        157        171        194        164        178
# 6769         246        233        248        249        236        251
# 8820         214        212        226        211        209        225
# 8834         228        210        215        234        218        221
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# ...

# %%
y1,y0,y2 = y1.drop("label",axis=1),y0.drop("label",axis=1),y2.drop("label",axis=1)

# %%
y1
# Out:
#       pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0           192        153        193        195        155        192
# 1            25         14         30         68         48         75
# 2           192        138        153        200        145        163
# 3            38         19         30         95         59         72
# 4           158        113        139        194        144        174
# ...         ...        ...        ...        ...        ...        ...
# 2457        230        172        198        229        166        195
# 2458        237        167        185        239        172        189
# 2459        221        151        175        223        153        176
# 2460        243        199        212        244        198        213
# 2461        238        194        217        243        200        223
#
#       pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2342  pixel2343  \
# ...

# %%
y0
# Out:
#       pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 64          163        135        159        167        140        166
# 1210        229        145        164        229        138        162
# 2976        237        160        159        239        160        161
# 2977        214        129        123        217        131        128
# 2978        215        156        171        215        158        173
# ...         ...        ...        ...        ...        ...        ...
# 9682         10          6          5         28         23         29
# 9683        194        173        176        202        182        184
# 9684         48         35         34        109         86         81
# 9685        151        116        123        204        162        174
# 9686         19          9         13         16          7         11
#
#       pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2342  pixel2343  \
# ...

# %%
y2
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 1211         151        126        129        161        132        138
# 1212         201        172        187        201        172        187
# 1213         137        117        136        145        124        144
# 1214           8          1          7         53         34         51
# 1215         223        204        225        235        218        240
# ...          ...        ...        ...        ...        ...        ...
# 2319         186        157        171        194        164        178
# 6769         246        233        248        249        236        251
# 8820         214        212        226        211        209        225
# 8834         228        210        215        234        218        221
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2342  pixel2343  \
# ...

# %%
y1.iloc[0].values.reshape((28,28,3))
# Out:
# array([[[192, 153, 193],
#         [195, 155, 192],
#         [197, 154, 185],
#         ...,
#         [193, 144, 153],
#         [197, 154, 163],
#         [194, 152, 160]],
#
#        [[197, 162, 202],
#         [201, 160, 197],
#         [202, 160, 193],
#         ...,
#         [194, 147, 149],
#         [198, 158, 166],
#         [192, 153, 167]],
#
#        [[197, 155, 193],
#         [198, 154, 185],
#         [202, 156, 191],
#         ...,
#         [194, 149, 152],
#         [199, 161, 177],
#         [194, 156, 175]],
#
#        ...,
#
#        [[194, 157, 191],
#         [206, 173, 206],
#         [206, 165, 192],
#         ...,
#         [191, 155, 183],
#         [193, 159, 187],
#         [193, 163, 197]],
#
#        [[187, 154, 185],
#         [203, 171, 199],
#         [202, 161, 183],
#         ...,
#         [178, 131, 148],
#         [187, 152, 174],
#         [190, 159, 189]],
#
#        [[171, 136, 164],
#         [191, 153, 179],
#         [196, 155, 176],
# ...

# %%
y1.head(5).values
# Out:
# array([[192, 153, 193, ..., 185, 154, 177],
#        [ 25,  14,  30, ...,  25,  14,  27],
#        [192, 138, 153, ..., 136, 104, 117],
#        [ 38,  19,  30, ...,  25,  12,  15],
#        [158, 113, 139, ..., 109,  78,  92]], dtype=int64)

# %%
j=0
for i in y2.head(5).values:
    i = i.reshape((28,28,3))
    cv2.imwrite("Classes/Melanoma_2/{}.jpg".format(j),i)
    j+=1
